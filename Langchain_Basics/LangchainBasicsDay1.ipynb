# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    base_url="http://localhost:11434",
    model="qwen3:8b",
    temperature=0.5,
    num_predict=2202,
    reasoning=False

)

response = llm.invoke("Hello India, how are you doing today?")
print(response.content)
# Out:
# Hello! I'm just a virtual assistant, not from India, but I'd love to chat with you! How are you doing today? 😊

# %%
# Prompt and chat templeates


from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template("ollama  {env}")
prompt =  prompt_template.invoke({"env" :"hi"})
# prompt

contents =  llm.invoke(prompt).content
contents
# Out:
# "Hello! I'm Qwen, a large language model developed by Alibaba Cloud. How can I assist you today?"

# %%
# Load ENV file
import os

from dotenv import load_dotenv
load = load_dotenv(".env")
print("LANGSMITH_API_KEY is configured:", bool(os.getenv("LANGSMITH_API_KEY")))
print("LANGSMITH_TRACING is enabled:", bool(os.getenv("LANGSMITH_TRACING")))
# Out:
# Load and print API key: [redacted]
# Load and print API key: true

# %%
import sys
import importlib.metadata as metadata

packages = [
    "langchain",
    "langchain-core",
    "langchain-community",
    "langchain-ollama",
    "ollama",
    "python-dotenv",
    "langsmith",
]

print("Python:", sys.version)

for package in packages:
    try:
        print(f"{package}: {metadata.version(package)}")
    except metadata.PackageNotFoundError:
        print(f"{package}: Not installed")
# Out:
# Python: 3.14.7 (tags/v3.14.7:823f032, Aug  5 2026, 10:51:32) [MSC v.1944 64 bit (AMD64)]
# langchain: 1.3.18
# langchain-core: 1.6.1
# langchain-community: Not installed
# langchain-ollama: 1.1.0
# ollama: 0.6.2
# python-dotenv: 1.2.3
# langsmith: 0.12.1

# %%
# Chat prompot template


from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate, SystemMessagePromptTemplate

systemMessage = SystemMessagePromptTemplate.from_template("you are and 10+ years experianced SDET")
humansMessage = HumanMessagePromptTemplate.from_template("What is {env}")

prompt_template = ChatPromptTemplate([
   systemMessage,
   humansMessage
])

prompt = prompt_template.invoke({"env": "LLM explain me 10 tokens of langchain"})

response = llm.invoke(prompt).content
print(llm)
print(type(response))

response
# Out:
# metadata={'lc_versions': {'langchain-core': '1.6.1', 'langchain': '1.3.18'}} model='qwen3:8b' reasoning=False num_predict=2202 temperature=0.5 base_url='http://localhost:11434'
# <class 'str'>
# "Sure! Here's a **10-token explanation** of **LLM** (Large Language Model) in the context of **LangChain**:\n\n---\n\n**LLM** is a **large language model** used in **LangChain** to generate, reason, and interact with text. It powers **chain** execution, **prompt engineering**, and **agent** behavior. **LangChain** provides tools to **integrate**, **manage**, and **scale** LLM usage efficiently.\n\n---\n\nLet me know if you'd like a breakdown of each token or a more detailed explanation!"

# %% [markdown]
# <!-- Message placeholder -->

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

prompt = ChatPromptTemplate([
    ("system", "You are an SDET"),
    MessagesPlaceholder("history"),
    ("human", "{question}")
])

messages = prompt.invoke({
    "history": [
        ("human", "What is Appium?"),
        ("ai", "Appium is a mobile automation tool.")
    ],
    "question": "How does it work?"
})

print(messages)

response = llm.invoke(messages)

print(response.content)
print(type(response))
# Out:
# messages=[SystemMessage(content='You are an SDET', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is Appium?', additional_kwargs={}, response_metadata={}), AIMessage(content='Appium is a mobile automation tool.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='How does it work?', additional_kwargs={}, response_metadata={})]
# Appium is an open-source mobile application automation testing tool that allows you to write tests in any language, such as Java, Python, JavaScript, Ruby, etc. It works by using a **WebDriver JSON Wire Protocol** to communicate with mobile devices, and it supports both **Native** and **Hybrid** mobile apps.
#
# ### How Appium Works:
#
# 1. **WebDriver JSON Wire Protocol**:
#    - Appium uses the WebDriver protocol over HTTP, which is the same protocol used by Selenium for web automation.
#    - This allows Appium to communicate with the device and send commands to the app under test.
#
# 2. **Device Communication**:
#    - Appium can communicate with **Android** and **iOS** devices through:
#      - **Android Debug Bridge (ADB)** for Android devices.
#      - **Instrumentation** for iOS devices (via Xcode).
#
# 3. **UIAutomator (Android)** and **XCUITest (iOS)**:
#    - On Android, Appium uses **UIAutomator** (a framework provided by Android) to interact with the app.
#    - On iOS, it uses **XCUITest** (a framework provided by Apple).
#
# 4. **No Need for Special SDKs**:
#    - Appium does **not** require you to install any special SDKs or modify the app source code to run tests.
#    - It can test apps that are already installed on the device.
#
# 5. **Cross-Platform Support**:
#    - Appium supports both **Android** and **iOS** devices.
#    - It also supports **Windows** (for Windows apps) via **Windows App Driver**.
#
# 6. **Test Script Languages**:
#    - You can write test scripts in any language that supports WebDriver, such as:
#      - Java
#      - Python
#      - JavaScript (Node.js)
#      - Ruby
#      - C#
#      - PHP
#      - etc.
#
# ### Summary:
# Appium works by using the WebDriver protocol to communicate with mobile devices, leveraging platform-specific frameworks (like UIAutomator for Android and XCUITest for iOS) to interact with the apps. It allows you to write cross-platform tests in any language, making it a popular choice for mobile automation testing.
# <class 'langchain_core.messages.ai.AIMessage'>

# %%
from langchain_core.messages import HumanMessage, AIMessage
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

history = []

prompt = ChatPromptTemplate([
    ("system", "You are an SDET"),
    MessagesPlaceholder("history"),("human", "{question}")
])

question = input("Ask a question: ")

messages = prompt.invoke({
    "history": history,
    "question": question
})

response = llm.invoke(messages)

print(response.content)

history.append(HumanMessage(content=question))
history.append(AIMessage(content=response.content))
